# %%
x="hello world"
print (x)
# Out:
# hello world

# %%
x=20
print (x)
# Out:
# 20

# %%
x=18.2
print (x)
# Out:
# 18.2

# %%
x=2j
print(x)
# Out:
# 2j

# %%
x="true"
print(x)
# Out:
# true

# %%
x=18
y=2
print(x+y)
# Out:
# 20

# %%
x=range(5)
print(x)
# Out:
# range(0, 5)

# %%
a=25
b=7
print(a-b)
# Out:
# 18

# %%
v=20
d=29
print(v*d)
# Out:
# 580

# %%
r=100
d=2
print(r/d)
# Out:
# 50.0
